# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
data=pd.read_csv('C:\\Users\\KHAVIN\\Downloads\\Book1.csv')
display(data.head(10))
# Out:
#    year      name   income  expenditure
# 0  2001       raju   10000         5000
# 1  2002       ragu   20000         6000
# 2  2003       ravi   30000         2000
# 3  2004       ramu   50000         1000
# 4  2005     logesh   60000        10000
# 5  2006      revan   50000         6000
# 6  2007      rahul   45000         5000
# 7  2008  raviendar  200000         3000

# %%
plt.scatter(data['year'],data['expenditure'])
plt.title("scatter plot")
plt.xlabel('year')
plt.ylabel('expenditure')
plt.show()

# %%
plt.plot(data['year'])
plt.plot(data['expenditure'])
plt.title("line chart")
plt.xlabel('year')
plt.ylabel('expenditure')
plt.show()

# %%
plt.bar(data['year'],data['expenditure'])
plt.title("Bar chart")
plt.xlabel('year')
plt.ylabel('expenditure')
plt.show()

# %%
plt.hist(data['income'])
plt.title("Histogram")
plt.show()
